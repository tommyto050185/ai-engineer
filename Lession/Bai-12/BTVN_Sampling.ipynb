# %% [markdown]
# # Bài tập về nhà: Lấy mẫu dữ liệu

# %%
import pandas as pd
import numpy as np

# Load the dataset
try:
    df = pd.read_csv('../../data/US Import.csv', delimiter=';', decimal=',')
    # Convert 'Value (US$)' to numeric, coercing errors to NaN
    df['Value (US$)'] = pd.to_numeric(df['Value (US$)'], errors='coerce')
    # Drop rows with NaN values in 'Value (US$)'
    df.dropna(subset=['Value (US$)'], inplace=True)
    df['Date'] = pd.to_datetime(df['Date'])
    print("Data loaded successfully")
    print(df.head())
except FileNotFoundError:
    print("File not found. Please check the file path.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Data loaded successfully
#         Date Import Country (Source)  \
# 0 2025-02-28                     USA
# 1 2025-02-28                     USA
# 2 2025-02-27                     USA
# 3 2025-02-26                     USA
# 4 2025-02-26                     USA
#
#                                             Exporter  \
# 0                    SUMEC MACHINERY ELECTRIC CO LTD
# 1    GUANGZHOU HUIKANG ELECTRONIC TECHNO LOGY CO LTD
# 2  XUZHOU HEALTHLAND SAUNA EQUIPMENT C WEST OF XUPEI
# 3                      ZHEJIANG CAFTP SERVICE CO LTD
# 4       ZHEJIANG TIANZHIXIN SPORTS EQUIPMEN T CO LTD
#
#                               Importer  HS Code Country of Origin  \
# 0  FIRMAN POWER EQUIPMENT INCORPORATED   851390             CHINA
# 1               CHAI VISION IMPORT LLC   851390             CHINA
# 2            CHAI VISION IMPORT NJ INC   851390             CHINA
# 3                          AYESPRO LLC   851390             CHINA
# 4               CHAI VISION IMPORT LLC   851390             CHINA
#
#   Country of Destination  Quantity Qty Unit   Weight Wgt Unit  Value (US$)  \
# 0          UNITED STATES     192.0      PKG  19680.0       KG    515637.13
# 1          UNITED STATES     215.0      CTN   2506.0       KG     65659.89
# 2          UNITED STATES      57.0      CTN   3724.0       KG     97572.80
# 3          UNITED STATES    1049.0      CTN   9110.0       KG    238691.78
# 4          UNITED STATES     400.0      CTN   3200.0       KG     83843.44
#
#   Transport Mode   Products
# 0       MARITIME  GENERATOR
# 1       MARITIME      SAUNA
# 2       MARITIME      SAUNA
# 3       MARITIME     LIGHTS
# 4       MARITIME      SAUNA

# %% [markdown]
# ### a. Dùng hàm describe để thực hiện thống kê mô tả cho toàn bộ dữ liệu

# %%
# Thống kê mô tả
df.describe()
# Out:
#             HS Code     Quantity         Weight   Value (US$)count  6.185000e+03  6185.000000    6185.000000  6.185000e+03mean   1.385053e+08   635.528912   14102.567683  1.755716e+05std    1.082576e+10  1204.656437   26173.165892  4.960320e+05min    8.513900e+05     1.000000       1.000000  0.000000e+0025%    8.513900e+05    16.000000    2771.000000  0.000000e+0050%    8.513900e+05    44.000000    8000.000000  0.000000e+0075%    8.513900e+05   759.000000   10824.000000  1.082104e+05max    8.513900e+11  9296.000000  255559.000000  4.450822e+06

# %% [markdown]
# ### b. Lấy mẫu 30 giao dịch nhập khẩu bằng phương pháp Simple Random Sampling (Lấy mẫu ngẫu nhiên đơn giản)

# %%
# Lấy mẫu ngẫu nhiên đơn giản
simple_random_sample = df.sample(n=30, random_state=42)
print(simple_random_sample)
# Out:
#                      Date Import Country (Source)  \
# 5485  2023-02-28 00:00:00                     USA
# 4094  2023-06-16 00:00:00                     USA
# 5180  2023-04-10 00:00:00                     USA
# 5684  2023-02-07 00:00:00                     USA
# 4753  2023-05-10 00:00:00                     USA
# 3326  2023-08-10 00:00:00                     USA
# 4055  2023-06-20 00:00:00                     USA
# 4421  2023-05-31 00:00:00                     USA
# 4981  2023-04-20 00:00:00                     USA
# 4523  2023-05-25 00:00:00                     USA
# 712   2024-09-11 00:00:00                     USA
# 3541  2023-07-25 00:00:00                     USA
# 4848  2023-05-03 00:00:00                     USA
# 1893  2024-02-20 00:00:00                     USA
# 469   2024-10-15 00:00:00                     USA
# 3617  2023-07-19 00:00:00                     USA
# 80    2025-02-01 00:00:00                     USA
# 3574  2023-07-19 00:00:00                     USA
# 4350  2023-05-31 00:00:00                     USA
# 4400  2023-05-31 00:00:00                     USA
# 4309  2023-06-03 00:00:00                     USA
# 393   2024-10-26 00:00:00                     USA
# 1533  2024-04-08 00:00:00                     USA
# 3459  2023-08-03 00:00:00                     USA
# 5319  2023-03-21 00:00:00                     USA
# 3206  2023-09-02 00:00:00                     USA
# 763   2024-09-04 00:00:00                     USA
# 2440  2023-11-22 00:00:00                     USA
# 747   2024-09-07 00:00:00                     USA
# 2453  2023-11-22 00:00:00                     USA
#
#                                                Exporter  \
# 5485                                                NaN
# 4094                       YANTAI RIMA MACHINERY CO LTD
# 5180                                                NaN
# 5684                  TECH COM SHANGHAI COMPUTER CO LTD
# 4753                                                NaN
# 3326                                                NaN
# 4055                                                NaN
# 4421                                                NaN
# 4981                                                NaN
# 4523                                                NaN
# 712                   SCHENKER CHINA LTD CHENGDU BRANCH
# 3541                                                NaN
# 4848                                                NaN
# 1893  FOSHAN WUCHEN INFORMATION TECHNOLOG XINGHUI GA...
# 469           HONGFUJIN PRECISION ELECTRONICS CH WST PK
# 3617                                                NaN
# 80                     LONGWIN POWER TECHNOLOGY COMPANY
# 3574                                                NaN
# 4350                                                NaN
# 4400                                                NaN
# 4309                                                NaN
# 393                        THE GREAT OCEAN LINE PTE LTD
# 1533                                 HONDA MOTOR CO LTD
# 3459        HONGFUJIN PRECISION ELECTRON CHENGDU CO LTD
# 5319                  TECH COM SHANGHAI COMPUTER CO LTD
# 3206                   ZHEJIANG ERA SOLAR TECHNOLOGY CO
# 763                                             UNKNOWN
# 2440                  SCHENKER CHINA LTD CHENGDU BRANCH
# 747                     SUMEC MACHINERY ELECTRIC CO LTD
# 2453                                 SCHENKER CHINA LTD
#
#                                  Importer  HS Code Country of Origin  \
# 5485                              UNKNOWN   851390             CHINA
# 4094                       PATRICK BOWDEN   851390             CHINA
# 5180                              UNKNOWN   851390             CHINA
# 5684        AI RETAIL HUB EAST C O GEODIS   851390             CHINA
# 4753                              UNKNOWN   851390             CHINA
# 3326                              UNKNOWN   851390             CHINA
# 4055                              UNKNOWN   851390             CHINA
# 4421                              UNKNOWN   851390             CHINA
# 4981                              UNKNOWN   851390             CHINA
# 4523                              UNKNOWN   851390             CHINA
# 712     SCHENKER INC AS AGENT OF SCHENKER   851390             CHINA
# 3541                              UNKNOWN   851390             CHINA
# 4848                              UNKNOWN   851390             CHINA
# 1893                 COTTI TECHNOLOGY INC   851390             CHINA
# 469         AI RETAIL HUB WEST C O GEODIS   851390             CHINA
# 3617                              UNKNOWN   851390             CHINA
# 80              GENERAC POWER SYSTEMS INC   851390           VIETNAM
# 3574                              UNKNOWN   851390             CHINA
# 4350                              UNKNOWN   851390             CHINA
# 4400                              UNKNOWN   851390             CHINA
# 4309                              UNKNOWN   851390             CHINA
# 393                           DB SCHENKER   851390             CHINA
# 1533                     HONDA CANADA INC   851390             JAPAN
# 3459           AI RETAIL HUB EAST C O OHL   851390             CHINA
# 5319        AI RETAIL HUB EAST C O GEODIS   851390             CHINA
# 3206               MIYA INTERNATIONAL LLC   851390             CHINA
# 763                               UNKNOWN   851390           VIETNAM
# 2440    SCHENKER INC AS AGENT OF SCHENKER   851390             CHINA
# 747   FIRMAN POWER EQUIPMENT INCORPORATED   851390             CHINA
# 2453               SCHENKER OF CANADA LTD   851390             CHINA
#
#      Country of Destination  Quantity Qty Unit   Weight Wgt Unit  Value (US$)  \
# 5485          UNITED STATES    1560.0      CTN   3954.0       KG         0.00
# 4094          UNITED STATES       4.0      PKG    600.0       KG      2000.00
# 5180          UNITED STATES      44.0      PKG   8519.0       KG         0.00
# 5684          UNITED STATES    1209.0      CTN   4806.0       KG         0.00
# 4753          UNITED STATES       7.0      PKG   1345.0       KG         0.00
# 3326          UNITED STATES      20.0      PKG   3850.0       KG         0.00
# 4055          UNITED STATES     360.0      CTN    898.0       KG         0.00
# 4421          UNITED STATES    1490.0      CTN   3767.0       KG         0.00
# 4981          UNITED STATES      27.0      PKG   5275.0       KG         0.00
# 4523          UNITED STATES       9.0      PKG   1741.0       KG         0.00
# 712           UNITED STATES      44.0      PKG   8741.0       KG    229023.58
# 3541          UNITED STATES      44.0      PKG   8750.0       KG         0.00
# 4848          UNITED STATES       9.0      PKG   1896.0        K         0.00
# 1893          UNITED STATES     291.0      CTN   7410.0       KG    194149.96
# 469           UNITED STATES      17.0      PKG   4438.0       KG    116280.36
# 3617          UNITED STATES       5.0      PKG   1401.0       KG         0.00
# 80            UNITED STATES     768.0      PCS  65896.0       KG   1490953.03
# 3574          UNITED STATES       7.0      PKG   1643.0       KG         0.00
# 4350          UNITED STATES      40.0      PKG   8000.0       KG         0.00
# 4400          UNITED STATES      21.0      PKG   6271.0       KG         0.00
# 4309          UNITED STATES     209.0      CTN   1653.0       KG         0.00
# 393           UNITED STATES      42.0      PKG  10964.0       KG    287268.57
# 1533          UNITED STATES      48.0      CTN   1632.0       KG     32640.00
# 3459          UNITED STATES      15.0      PKG   2799.0       KG         0.00
# 5319          UNITED STATES    3967.0      CTN   9637.0       KG         0.00
# 3206          UNITED STATES    1113.0      CTN   9292.0       KG         0.00
# 763           UNITED STATES    1452.0      CTN   9060.0       KG    204990.20
# 2440          UNITED STATES       9.0      PKG   1749.0       KG         0.00
# 747           UNITED STATES     564.0      CTN  70026.0       KG   1834756.38
# 2453          UNITED STATES    5160.0      CTN  12632.0       KG         0.00
#
#      Transport Mode       Products
# 5485       MARITIME       COMPUTER
# 4094       MARITIME        SAWMILL
# 5180       MARITIME       COMPUTER
# 5684       MARITIME       COMPUTER
# 4753       MARITIME       COMPUTER
# 3326       MARITIME       COMPUTER
# 4055       MARITIME       COMPUTER
# 4421       MARITIME       COMPUTER
# 4981       MARITIME       COMPUTER
# 4523       MARITIME       COMPUTER
# 712        MARITIME       COMPUTER
# 3541       MARITIME       COMPUTER
# 4848       MARITIME       COMPUTER
# 1893       MARITIME            CAR
# 469        MARITIME       COMPUTER
# 3617       MARITIME       COMPUTER
# 80         MARITIME      GENERATOR
# 3574       MARITIME       COMPUTER
# 4350       MARITIME       COMPUTER
# 4400       MARITIME       COMPUTER
# 4309       MARITIME  ELECTRIC LAMP
# 393        MARITIME       COMPUTER
# 1533       MARITIME      GENERATOR
# 3459       MARITIME       COMPUTER
# 5319       MARITIME       COMPUTER
# 3206       MARITIME         LIGHTS
# 763        MARITIME       COMPUTER
# 2440       MARITIME       COMPUTER
# 747        MARITIME      GENERATOR
# 2453       MARITIME       COMPUTER

# %% [markdown]
# ### c. Lấy mẫu 30 giao dịch nhập khẩu bằng phương pháp Stratified Sampling (Lấy mẫu phân tầng)

# %%
# Lấy mẫu phân tầng theo cột 'Products'
# We will take 1 sample from 30 different products to ensure diversity.
# This is a form of stratified sampling.
# Get products with at least one sample
products = df['Products'].unique()
# Randomly select 30 products
sampled_products = np.random.choice(products, 30, replace=False)
# Group by the selected products and take 1 sample from each
stratified_sample = df[df['Products'].isin(sampled_products)].groupby('Products').sample(n=1, random_state=42)
print(stratified_sample)

# %% [markdown]
# ### d. Lấy mẫu 30 giao dịch nhập khẩu bằng phương pháp Systematic Sampling (Lấy mẫu hệ thống)

# %%
# Lấy mẫu hệ thống
n = 30
N = len(df)
k = int(N / n)
start = np.random.randint(0, k)
systematic_sample = df.iloc[start::k].head(n)
print(systematic_sample)

# %% [markdown]
# ### e. Lấy mẫu 30 giao dịch nhập khẩu bằng phương pháp Cluster Sampling (Lấy mẫu cụm)

# %%
# Lấy mẫu cụm
# Sử dụng cột 'Products' làm cụm
clusters = df['Products'].unique()
random_clusters = np.random.choice(clusters, size=3, replace=False)
cluster_sample = df[df['Products'].isin(random_clusters)]
# If the sample is larger than 30, take a random sample of 30 from it
if len(cluster_sample) > 30:
    cluster_sample = cluster_sample.sample(n=30, random_state=42)
print(cluster_sample)

# %% [markdown]
# ### f. Phương pháp lấy mẫu nào cho kết quả trung bình chính xác nhất?

# %%
# Tính giá trị trung bình của 'Value (US$)' từ toàn bộ dữ liệu
population_mean = df['Value (US$)'].mean()

# Tính giá trị trung bình của các mẫu
simple_random_mean = simple_random_sample['Value (US$)'].mean()
stratified_mean = stratified_sample['Value (US$)'].mean()
systematic_mean = systematic_sample['Value (US$)'].mean()
cluster_mean = cluster_sample['Value (US$)'].mean()

# So sánh
print(f"Population Mean: {population_mean}")
print(f"Simple Random Sample Mean: {simple_random_mean}, Difference: {abs(population_mean - simple_random_mean)}")
print(f"Stratified Sample Mean: {stratified_mean}, Difference: {abs(population_mean - stratified_mean)}")
print(f"Systematic Sample Mean: {systematic_mean}, Difference: {abs(population_mean - systematic_mean)}")
print(f"Cluster Sample Mean: {cluster_mean}, Difference: {abs(population_mean - cluster_mean)}")

# %% [markdown]
# ### g. Hãy rút ra kết luận khi nào nên sử dụng các phương pháp lấy mẫu khác nhau
#
# **Simple Random Sampling (Lấy mẫu ngẫu nhiên đơn giản):**
# - **Khi nào:** Sử dụng khi tổng thể (population) tương đối đồng nhất (homogeneous).
# - **Ưu điểm:** Dễ thực hiện, mỗi phần tử có cơ hội được chọn như nhau.
# - **Nhược điểm:** Có thể không đại diện tốt cho tổng thể nếu tổng thể không đồng nhất, có thể bỏ sót các nhóm nhỏ.
#
# **Stratified Sampling (Lấy mẫu phân tầng):**
# - **Khi nào:** Sử dụng khi tổng thể không đồng nhất và có thể chia thành các nhóm (tầng - strata) có ý nghĩa, trong đó mỗi tầng lại tương đối đồng nhất. Ví dụ: chia khách hàng theo độ tuổi, giới tính, địa lý.
# - **Ưu điểm:** Đảm bảo các nhóm nhỏ trong tổng thể được đại diện trong mẫu, cho kết quả chính xác hơn so với lấy mẫu ngẫu nhiên đơn giản.
# - **Nhược điểm:** Cần biết thông tin về các tầng trong tổng thể, phức tạp hơn trong việc triển khai.
#
# **Systematic Sampling (Lấy mẫu hệ thống):**
# - **Khi nào:** Sử dụng khi có một danh sách các phần tử trong tổng thể và các phần tử được sắp xếp một cách ngẫu nhiên hoặc không theo một chu kỳ nào có thể ảnh hưởng đến kết quả.
# - **Ưu điểm:** Dễ thực hiện hơn lấy mẫu ngẫu nhiên đơn giản, có thể cho kết quả đại diện tốt nếu danh sách được sắp xếp ngẫu nhiên.
# - **Nhược điểm:** Nếu có một chu kỳ trong danh sách và khoảng lấy mẫu (k) trùng với chu kỳ đó, mẫu sẽ bị sai lệch.
#
# **Cluster Sampling (Lấy mẫu cụm):**
# - **Khi nào:** Sử dụng khi tổng thể được chia thành các cụm (cluster) tự nhiên và việc lấy mẫu các phần tử riêng lẻ là khó khăn hoặc tốn kém. Các cụm thường không đồng nhất bên trong. Ví dụ: lấy mẫu các hộ gia đình trong một thành phố (mỗi khu phố là một cụm).
# - **Ưu điểm:** Tiết kiệm chi phí và thời gian, đặc biệt khi tổng thể phân tán về mặt địa lý.
# - **Nhược điểm:** Kém chính xác hơn các phương pháp khác nếu các cụm không đại diện tốt cho toàn bộ tổng thể (các cụm quá khác nhau).
